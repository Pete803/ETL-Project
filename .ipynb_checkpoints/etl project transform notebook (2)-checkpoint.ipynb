# %%
import pandas as pd

a = pd.read_csv("/Users/alexandergoldstein/Downloads/leadsampling_2014.csv")
b = pd.DataFrame(a)

c = pd.read_csv("/Users/alexandergoldstein/Downloads/leadsampling_2015.csv")
d = pd.DataFrame(c)

e = pd.read_csv("/Users/alexandergoldstein/Downloads/CHA003_PWS_Lead_Public-drinking-water-lead-levels.csv")
f = pd.DataFrame(e)

# %%
g = [b, d]
h = pd.concat(g)
print(len(h))
print(len(f))
# Out:
# 4467
# 13202

# %%
f['COLLECT_DT'] = pd.to_datetime(f['COLLECT_DT'])
i = "01-01-2014"
j = (f['COLLECT_DT'] >= i)
k = f.loc[j]

# %%
l = "02-01-2014"
m = (k['COLLECT_DT'] < l)
n = k.loc[m]

o = "03-01-2014"
p = (k['COLLECT_DT'] >= l) & (k['COLLECT_DT'] < o)
q = k.loc[p]

r = "04-01-2014"
s = (k['COLLECT_DT'] >= o) & (k['COLLECT_DT'] < r)
t = k.loc[s]

u = "05-01-2014"
v = (k['COLLECT_DT'] >= r) & (k['COLLECT_DT'] < u)
w = k.loc[v]

x = "6-01-2014"
y = (k['COLLECT_DT'] >= u) & (k['COLLECT_DT'] < x)
z = k.loc[y]

aa = "07-01-2014"
ab = (k['COLLECT_DT'] >= x) & (k['COLLECT_DT'] < aa)
ac = k.loc[ab]

ad = "08-01-2014"
ae = (k['COLLECT_DT'] >= aa) & (k['COLLECT_DT'] < ad)
af = k.loc[ae]

ag = "09-01-2014"
ah = (k['COLLECT_DT'] >= ad) & (k['COLLECT_DT'] < ag)
ai = k.loc[ah]

aj = "10-01-2014"
ak = (k['COLLECT_DT'] >= ag) & (k['COLLECT_DT'] < aj)
al = k.loc[ak]

am = "11-01-2014"
an = (k['COLLECT_DT'] >= aj) & (k['COLLECT_DT'] < am)
ao = k.loc[an]

ap = "12-01-2014"
aq = (k['COLLECT_DT'] >= am) & (k['COLLECT_DT'] < ap)
ar = k.loc[aq]

at = "01-01-2015"
au = (k['COLLECT_DT'] >= ap) & (k['COLLECT_DT'] < at)
av = k.loc[au]

aw = "02-01-2015"
ax = (k['COLLECT_DT'] >= at) & (k['COLLECT_DT'] < aw)
ay = k.loc[ax]

az = "03-01-2015"
ba = (k['COLLECT_DT'] >= aw) & (k['COLLECT_DT'] < az)
bb = k.loc[ba]

bc = "04-01-2015"
bd = (k['COLLECT_DT'] >= az) & (k['COLLECT_DT'] < bc)
be = k.loc[bd]

bf = "05-01-2015"
bg = (k['COLLECT_DT'] >= bc) & (k['COLLECT_DT'] < bf)
bh = k.loc[bg]

bi = "06-01-2015"
bj = (k['COLLECT_DT'] >= bf) & (k['COLLECT_DT'] < bi)
bk = k.loc[bj]

bl = "07-01-2015"
bm = (k['COLLECT_DT'] >= bi) & (k['COLLECT_DT'] < bl)
bn = k.loc[bm]

bo = "08-01-2015"
bp = (k['COLLECT_DT'] >= bl) & (k['COLLECT_DT'] < bo)
bq = k.loc[bp]

br = "09-01-2015"
bs = (k['COLLECT_DT'] >= bo) & (k['COLLECT_DT'] < br)
bt = k.loc[bs]

bu = "10-01-2015"
bv = (k['COLLECT_DT'] >= br) & (k['COLLECT_DT'] < bu)
bw = k.loc[bv]

bx = "11-01-2015"
by = (k['COLLECT_DT'] >= bu) & (k['COLLECT_DT'] < bx)
bz = k.loc[by]

ca = "12-01-2015"
cb = (k['COLLECT_DT'] >= bx) & (k['COLLECT_DT'] < ca)
cc = k.loc[cb]

dx = (k['COLLECT_DT'] >= ca)
dy = k.loc[dx]

# %%
h['Sampled Date'] = pd.to_datetime(h['Sampled Date'])

ce = (h['Sampled Date'] <= l)
cf = h.loc[ce]

# %%
cd = (h['Sampled Date'] >= l) & (h['Sampled Date'] < o)
cg = h.loc[cd]

ch = (h['Sampled Date'] >= o) & (h['Sampled Date'] < r)
ci = h.loc[ch]

cj = (h['Sampled Date'] >= r) & (h['Sampled Date'] < u)
ck = h.loc[cj]

cl = (h['Sampled Date'] >= u) & (h['Sampled Date'] < x)
cm = h.loc[cl]

cn = (h['Sampled Date'] >= x) & (h['Sampled Date'] < aa)
co = h.loc[cn]

cp = (h['Sampled Date'] >= aa) & (h['Sampled Date'] < ad)
cq = h.loc[cp]

cr = (h['Sampled Date'] >= ad) & (h['Sampled Date'] < ag)
cs = h.loc[cr]

ct = (h['Sampled Date'] >= ag) & (h['Sampled Date'] < aj)
cu = h.loc[ct]

cv = (h['Sampled Date'] >= aj) & (h['Sampled Date'] < am)
cw = h.loc[cv]

cx = (h['Sampled Date'] >= am) & (h['Sampled Date'] < ap)
cy = h.loc[cx]

cz = (h['Sampled Date'] >= ap) & (h['Sampled Date'] < at)
da = h.loc[cz]

db = (h['Sampled Date'] >= at) & (h['Sampled Date'] < aw)
dc = h.loc[db]

dd = (h['Sampled Date'] >= aw) & (h['Sampled Date'] < az)
de = h.loc[dd]

df = (h['Sampled Date'] >= az) & (h['Sampled Date'] < bc)
dg = h.loc[df]

dh = (h['Sampled Date'] >= bc) & (h['Sampled Date'] < bf)
di = h.loc[dh]

dj = (h['Sampled Date'] >= bf) & (h['Sampled Date'] < bi)
dk = h.loc[dj]

dl = (h['Sampled Date'] >= bi) & (h['Sampled Date'] < bl)
dm = h.loc[dl]

dn = (h['Sampled Date'] >= bl) & (h['Sampled Date'] < bo)
do = h.loc[dn]

dp = (h['Sampled Date'] >= bo) & (h['Sampled Date'] < br)
dq = h.loc[dp]

dr = (h['Sampled Date'] >= br) & (h['Sampled Date'] < bu)
ds = h.loc[dr]

dt = (h['Sampled Date'] >= bu) & (h['Sampled Date'] < bx)
du = h.loc[dt]

dv = (h['Sampled Date'] >= bx) & (h['Sampled Date'] < ca)
dw = h.loc[dv]

dz = (h['Sampled Date'] >= ca)
ea = h.loc[dz]

# %%
print(len(n))
print(len(q))
print(len(t))
print(len(w))
print(len(z))
print(len(ac))
print(len(af))
print(len(ai))
print(len(al))
print(len(ao))
print(len(ar))
print(len(av))
print(len(ay))
print(len(bb))
print(len(be))
print(len(bh))
print(len(bk))
print(len(bn))
print(len(bq))
print(len(bt))
print(len(bw))
print(len(bz))
print(len(cc))
print(len(dy))
# Out:
# 11
# 1
# 86
# 30
# 97
# 769
# 886
# 1076
# 1255
# 50
# 84
# 221
# 2
# 24
# 18
# 55
# 217
# 817
# 665
# 1150
# 1220
# 50
# 163
# 126

# %%
print(len(ce))
print(len(cg))
print(len(ci))
print(len(ck))
print(len(cm))
print(len(co))
print(len(cq))
print(len(cs))
print(len(cu))
print(len(cw))
print(len(cy))
print(len(da))
print(len(dc))
print(len(de))
print(len(dg))
print(len(di))
print(len(dk))
print(len(dm))
print(len(do))
print(len(dq))
print(len(ds))
print(len(du))
print(len(dw))
print(len(ea))
# Out:
# 4467
# 40
# 45
# 81
# 1030
# 924
# 424
# 287
# 229
# 165
# 113
# 103
# 93
# 65
# 89
# 96
# 91
# 70
# 93
# 77
# 74
# 86
# 81
# 67

# %%
eb = ce.sample(n=11, random_state=1)
ec = cg.sample(n=1, random_state=1)
ed = t.sample(n=45, random_state=1)
ee = ck.sample(n=30, random_state=1)
ef = cm.sample(n=97, random_state=1)
eg = co.sample(n=769, random_state=1)
eh = af.sample(n=424, random_state=1)
ei = ai.sample(n=287, random_state=1)
ej = al.sample(n=229, random_state=1)
ek = cw.sample(n=50, random_state=1)
el = cy.sample(n=84, random_state=1)
em = av.sample(n=103, random_state=1)
en = dc.sample(n=2, random_state=1)
eo = de.sample(n=24, random_state=1)
ep = dg.sample(n=18, random_state=1)
eq = di.sample(n=55, random_state=1)
er = bk.sample(n=91, random_state=1)
es = bn.sample(n=70, random_state=1)
et = bq.sample(n=93, random_state=1)
eu = bt.sample(n=77, random_state=1)
ev = bw.sample(n=74, random_state=1)
ew = du.sample(n=50, random_state=1)
ex = cc.sample(n=81, random_state=1)
ey = dy.sample(n=67, random_state=1)

# %%
ez = [n, q, ed, w, z, ac, eh, ei, ej, ao, ar, em, ay, bb, be, bh, er, es, et, eu, ev, bz, ex, ey]
fb = pd.concat(ez)
fd = pd.DataFrame(fb)
print(fd)
# Out:
#                        PWSName  FIPS_5 CNTY_OR_CITY  POPULATION ANALYTE_NAME  \
# 2064           ACSA URBAN AREA   51003    ALBEMARLE       61673         LEAD
# 7571   DOCKSIDE HEALTH & REHAB   51119    MIDDLESEX         150         LEAD
# 7572   DOCKSIDE HEALTH & REHAB   51119    MIDDLESEX         150         LEAD
# 7573   DOCKSIDE HEALTH & REHAB   51119    MIDDLESEX         150         LEAD
# 7574   DOCKSIDE HEALTH & REHAB   51119    MIDDLESEX         150         LEAD
# ...                        ...     ...          ...         ...          ...
# 11006        CULPEPER, TOWN OF   51047     CULPEPER       16600         LEAD
# 140        LAUREL MEADOWS HOME   51035      CARROLL          90         LEAD
# 12302      ROUND HILL, TOWN OF   51107      LOUDOUN        3495         LEAD
# 547    PENNINGTON GAP, TOWN OF   51105          LEE        1781         LEAD
# 5454          WAVERLY, TOWN OF   51183       SUSSEX        2309         LEAD
#
#        Concentration in µg/L COLLECT_DT
# 2064                    0.00 2014-01-14
# 7571                    3.53 2014-01-28
# 7572                    0.00 2014-01-28
# 7573                    0.00 2014-01-28
# 7574                    2.98 2014-01-28
# ...                      ...        ...
# 11006                   0.00 2015-12-03
# 140                     0.00 2015-12-15
# 12302                   2.87 2015-12-21
# 547                     0.00 2015-12-08
# 5454                    0.00 2015-12-03
#
# [2832 rows x 7 columns]

# %%
fa = [eb, ec, ci, ee, ef, eg, cq, cs, cu, ek, el, da, en, eo, ep, eq, dk, dm, do, dq, ds, ew, dw, ea]
fc = pd.concat(fa)
print(fc)
# Out:
#           0 Lead Amount ppb Partial Postal Code  Sample Number Sampled Date
# 1673  False             NaN                 NaN            NaN          NaT
# 2030  False             NaN                 NaN            NaN          NaT
# 2606  False             NaN                 NaN            NaN          NaT
# 2743  False             NaN                 NaN            NaN          NaT
# 1884  False             NaN                 NaN            NaN          NaT
# ...     ...             ...                 ...            ...          ...
# 62      NaN          0.0605                 M4A      1842424.0   2015-12-02
# 63      NaN           0.640                 M4E      1830480.0   2015-12-01
# 64      NaN            1.26                 M4L      1828914.0   2015-12-01
# 65      NaN         <0.0500                 M1L      1828456.0   2015-12-01
# 66      NaN           0.583                 M4C      1828817.0   2015-12-01
#
# [2832 rows x 5 columns]

# %%
fd = pd.DataFrame(fb)
fe = pd.DataFrame(fc)
fl = fe.sort_values(by="Sampled Date")
fm = fd.sort_values(by="COLLECT_DT")
ff = fl['Lead Amount ppb']
fg = fl['Partial Postal Code']
fh = fl['Sampled Date']
fi = fd.join(ff)
fj = fi.join(fg)
fk = fj.join(fh)
print(fk)
# Out:
#                              PWSName  FIPS_5   CNTY_OR_CITY  POPULATION  \
# 95     CARROLL REGIONAL WATER SYSTEM   51035        CARROLL        7500
# 95     CARROLL REGIONAL WATER SYSTEM   51035        CARROLL        7500
# 95     CARROLL REGIONAL WATER SYSTEM   51035        CARROLL        7500
# 95     CARROLL REGIONAL WATER SYSTEM   51035        CARROLL        7500
# 95     CARROLL REGIONAL WATER SYSTEM   51035        CARROLL        7500
# ...                              ...     ...            ...         ...
# 13017      STAFFORD COUNTY UTILITIES   51179       STAFFORD      108039
# 13154              MANASSAS, CITY OF   51683       MANASSAS       38000
# 13174         MANASSAS PARK, CITY OF   51685  MANASSAS PARK       14050
# 13180         MANASSAS PARK, CITY OF   51685  MANASSAS PARK       14050
# 13185         MANASSAS PARK, CITY OF   51685  MANASSAS PARK       14050
#
#       ANALYTE_NAME  Concentration in µg/L COLLECT_DT Lead Amount ppb  \
# 95            LEAD                    0.0 2015-09-02         <0.0500
# 95            LEAD                    0.0 2015-09-02         <0.0500
# 95            LEAD                    0.0 2015-09-02         <0.0500
# 95            LEAD                    0.0 2015-09-02         <0.0500
# 95            LEAD                    0.0 2015-09-02         <0.0500
# ...            ...                    ...        ...             ...
# 13017         LEAD                    0.0 2015-05-04             NaN
# 13154         LEAD                    0.0 2015-08-05             NaN
# 13174         LEAD                    0.0 2015-09-22             NaN
# 13180         LEAD                    0.0 2015-09-17             NaN
# 13185         LEAD                    0.0 2015-09-15             NaN
#
#       Partial Postal Code Sampled Date
# 95                    M3B   2014-12-02
# 95                    M3B   2015-11-23
# 95                    M1N   2014-12-02
# 95                    M1N   2015-11-23
# 95                    M3B   2014-12-02
# ...                   ...          ...
# 13017                 NaN          NaT
# 13154                 NaN          NaT
# 13174                 NaN          NaT
# 13180                 NaN          NaT
# 13185                 NaN          NaT
#
# [3504 rows x 10 columns]

# %%
db1 = fl.to_csv('transform-2.csv')
db2 = fm.to_csv('transform-1.csv')
db1
db2
