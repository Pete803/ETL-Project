# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# ### Store CSV into DataFrame

# %%
csv_file_1 = "Resources/transform-1.csv"
virginia_df = pd.read_csv(csv_file_1)
virginia_df
# Out:
#       Unnamed: 0                  PWSName  FIPS_5 CNTY_OR_CITY  POPULATION  \
# 0           2064          ACSA URBAN AREA   51003    ALBEMARLE       61673
# 1           7571  DOCKSIDE HEALTH & REHAB   51119    MIDDLESEX         150
# 2           7572  DOCKSIDE HEALTH & REHAB   51119    MIDDLESEX         150
# 3           7573  DOCKSIDE HEALTH & REHAB   51119    MIDDLESEX         150
# 4           7574  DOCKSIDE HEALTH & REHAB   51119    MIDDLESEX         150
# ...          ...                      ...     ...          ...         ...
# 2827        9597           SHERWOOD MANOR   51089        HENRY          80
# 2828        9954      BURKEVILLE, TOWN OF   51135     NOTTOWAY         432
# 2829        9959      BURKEVILLE, TOWN OF   51135     NOTTOWAY         432
# 2830        9952      BURKEVILLE, TOWN OF   51135     NOTTOWAY         432
# 2831        9957      BURKEVILLE, TOWN OF   51135     NOTTOWAY         432
#
#      ANALYTE_NAME  Concentration in µg/L  COLLECT_DT
# 0            LEAD                   0.00  2014-01-14
# 1            LEAD                   3.53  2014-01-28
# 2            LEAD                   0.00  2014-01-28
# 3            LEAD                   0.00  2014-01-28
# 4            LEAD                   2.98  2014-01-28
# ...           ...                    ...         ...
# 2827         LEAD                   0.00  2015-12-30
# 2828         LEAD                   0.00  2015-12-30
# 2829         LEAD                   4.00  2015-12-30
# 2830         LEAD                   4.53  2015-12-30
# 2831         LEAD                   0.00  2015-12-30
#
# [2832 rows x 8 columns]

# %%
va_rename = virginia_df.rename(columns={"Concentration in µg/L":"Lead_Amount_mg_L"})
va_rename
# Out:
#       Unnamed: 0                  PWSName  FIPS_5 CNTY_OR_CITY  POPULATION  \
# 0           2064          ACSA URBAN AREA   51003    ALBEMARLE       61673
# 1           7571  DOCKSIDE HEALTH & REHAB   51119    MIDDLESEX         150
# 2           7572  DOCKSIDE HEALTH & REHAB   51119    MIDDLESEX         150
# 3           7573  DOCKSIDE HEALTH & REHAB   51119    MIDDLESEX         150
# 4           7574  DOCKSIDE HEALTH & REHAB   51119    MIDDLESEX         150
# ...          ...                      ...     ...          ...         ...
# 2827        9597           SHERWOOD MANOR   51089        HENRY          80
# 2828        9954      BURKEVILLE, TOWN OF   51135     NOTTOWAY         432
# 2829        9959      BURKEVILLE, TOWN OF   51135     NOTTOWAY         432
# 2830        9952      BURKEVILLE, TOWN OF   51135     NOTTOWAY         432
# 2831        9957      BURKEVILLE, TOWN OF   51135     NOTTOWAY         432
#
#      ANALYTE_NAME  Lead_Amount_mg_L  COLLECT_DT
# 0            LEAD              0.00  2014-01-14
# 1            LEAD              3.53  2014-01-28
# 2            LEAD              0.00  2014-01-28
# 3            LEAD              0.00  2014-01-28
# 4            LEAD              2.98  2014-01-28
# ...           ...               ...         ...
# 2827         LEAD              0.00  2015-12-30
# 2828         LEAD              0.00  2015-12-30
# 2829         LEAD              4.00  2015-12-30
# 2830         LEAD              4.53  2015-12-30
# 2831         LEAD              0.00  2015-12-30
#
# [2832 rows x 8 columns]

# %%
virginia_new = va_rename[['CNTY_OR_CITY', 'COLLECT_DT', 'Lead_Amount_mg_L']].copy()
virginia_new.head()
# Out:
#   CNTY_OR_CITY  COLLECT_DT  Lead_Amount_mg_L
# 0    ALBEMARLE  2014-01-14              0.00
# 1    MIDDLESEX  2014-01-28              3.53
# 2    MIDDLESEX  2014-01-28              0.00
# 3    MIDDLESEX  2014-01-28              0.00
# 4    MIDDLESEX  2014-01-28              2.98

# %%
csv_file_2 = "Resources/transform-2.csv"
toronto_df = pd.read_csv(csv_file_2)
toronto_df
# Out:
#       Unnamed: 0      0 Lead Amount ppb Partial Postal Code  Sample Number  \
# 0           3403    NaN          0.0600                 M1M      1551409.0
# 1           3400    NaN         <0.0500                 M3M      1555569.0
# 2           3399    NaN            2.60                 M6J      1556417.0
# 3           3398    NaN            2.50                 M6M      1555544.0
# 4           3397    NaN           0.690                 M4J      1556416.0
# ...          ...    ...             ...                 ...            ...
# 2827        1126  False             NaN                 NaN            NaN
# 2828        2099  False             NaN                 NaN            NaN
# 2829        3454   True             NaN                 NaN            NaN
# 2830        2534  False             NaN                 NaN            NaN
# 2831         843  False             NaN                 NaN            NaN
#
#      Sampled Date
# 0      2014-02-25
# 1      2014-03-02
# 2      2014-03-06
# 3      2014-03-07
# 4      2014-03-07
# ...           ...
# 2827          NaN
# 2828          NaN
# 2829          NaN
# 2830          NaN
# 2831          NaN
#
# [2832 rows x 6 columns]

# %%
toronto_new = toronto_df[['Partial Postal Code', 'Sampled Date', 'Lead Amount ppb']].copy()
toronto_new.head()
# Out:
#   Partial Postal Code Sampled Date Lead Amount ppb
# 0                 M1M   2014-02-25          0.0600
# 1                 M3M   2014-03-02         <0.0500
# 2                 M6J   2014-03-06            2.60
# 3                 M6M   2014-03-07            2.50
# 4                 M4J   2014-03-07           0.690

# %% [markdown]
# ### Connect to local database

# %%
rds_connection_string = "postgres:1234@localhost:5432/lead_water"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %% [markdown]
# ### Check for tables

# %%
engine.table_names()
# Out:
# ['virginia_lead']

# %% [markdown]
# ### Use pandas to load csv converted DataFrame into database

# %%
virginia_new.dtypes
# Out:
# CNTY_OR_CITY         object
# COLLECT_DT           object
# Lead_Amount_mg_L    float64
# dtype: object

# %%
virginia_new['CNTY_OR_CITY']=virginia_new['CNTY_OR_CITY'].astype("str")

# %% [markdown]
# ### Virginia - Create new data with select columns

# %%
virginia_new.to_sql(name='virginia_lead', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1256                     self.dialect.do_executemany(
# -> 1257                         cursor, statement, parameters, context
#    1258                     )
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     897         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 898             cursor.executemany(statement, parameters)
#     899             return
#
# UndefinedColumn: column "CNTY_OR_CITY" of relation "virginia_lead" does not exist
# LINE 1: INSERT INTO virginia_lead ("CNTY_OR_CITY", "COLLECT_DT", "Le...
#                                    ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-60-3494ec96771d> in <module>
# ----> 1 virginia_new.to_sql(name='virginia_lead', con=engine, if_exists='append', index=False)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2613             chunksize=chunksize,
#    2614             dtype=dtype,
# -> 2615             method=method,
#    2616         )
#    2617
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     596         chunksize=chunksize,
#     597         dtype=dtype,
# --> 598         method=method,
#     599     )
#     600
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1404                 raise ValueError("inf cannot be used with MySQL") from err
#    1405             else:
# -> 1406                 raise err
#    1407
#    1408         if not name.isdigit() and not name.islower():
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1396
#    1397         try:
# -> 1398             table.insert(chunksize, method=method)
#    1399         except exc.SQLAlchemyError as err:
#    1400             # GH34431
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     828
#     829                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 830                 exec_insert(conn, keys, chunk_iter)
#     831
#     832     def _query_iterator(
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     745         """
#     746         data = [dict(zip(keys, row)) for row in data_iter]
# --> 747         conn.execute(self.table.insert(), data)
#     748
#     749     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#    1009             )
#    1010         else:
# -> 1011             return meth(self, multiparams, params)
#    1012
#    1013     def _execute_function(self, func, multiparams, params):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     296     def _execute_on_connection(self, connection, multiparams, params):
#     297         if self.supports_execution:
# --> 298             return connection._execute_clauseelement(self, multiparams, params)
#     299         else:
#     300             raise exc.ObjectNotExecutableError(self)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1128             distilled_params,
#    1129             compiled_sql,
# -> 1130             distilled_params,
#    1131         )
#    1132         if self._has_events or self.engine._has_events:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1315         except BaseException as e:
#    1316             self._handle_dbapi_exception(
# -> 1317                 e, statement, parameters, cursor, context
#    1318             )
#    1319
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1509             elif should_wrap:
#    1510                 util.raise_(
# -> 1511                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1512                 )
#    1513             else:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1255                 if not evt_handled:
#    1256                     self.dialect.do_executemany(
# -> 1257                         cursor, statement, parameters, context
#    1258                     )
#    1259             elif not parameters and context.no_parameters:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     896     def do_executemany(self, cursor, statement, parameters, context=None):
#     897         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 898             cursor.executemany(statement, parameters)
#     899             return
#     900
#
# ProgrammingError: (psycopg2.errors.UndefinedColumn) column "CNTY_OR_CITY" of relation "virginia_lead" does not exist
# LINE 1: INSERT INTO virginia_lead ("CNTY_OR_CITY", "COLLECT_DT", "Le...
#                                    ^
#
# [SQL: INSERT INTO virginia_lead ("CNTY_OR_CITY", "COLLECT_DT", "Lead_Amount_mg_L") VALUES (%(CNTY_OR_CITY)s, %(COLLECT_DT)s, %(Lead_Amount_mg_L)s)]
# [parameters: ({'CNTY_OR_CITY': 'ALBEMARLE', 'COLLECT_DT': '2014-01-14', 'Lead_Amount_mg_L': 0.0}, {'CNTY_OR_CITY': 'MIDDLESEX', 'COLLECT_DT': '2014-01-28', 'Lead_Amount_mg_L': 3.53}, {'CNTY_OR_CITY': 'MIDDLESEX', 'COLLECT_DT': '2014-01-28', 'Lead_Amount_mg_L': 0.0}, {'CNTY_OR_CITY': 'MIDDLESEX', 'COLLECT_DT': '2014-01-28', 'Lead_Amount_mg_L': 0.0}, {'CNTY_OR_CITY': 'MIDDLESEX', 'COLLECT_DT': '2014-01-28', 'Lead_Amount_mg_L': 2.98}, {'CNTY_OR_CITY': 'MIDDLESEX', 'COLLECT_DT': '2014-01-28', 'Lead_Amount_mg_L': 0.0}, {'CNTY_OR_CITY': 'MIDDLESEX', 'COLLECT_DT': '2014-01-28', 'Lead_Amount_mg_L': 0.0}, {'CNTY_OR_CITY': 'MIDDLESEX', 'COLLECT_DT': '2014-01-28', 'Lead_Amount_mg_L': 0.0}  ... displaying 10 of 2832 total bound parameter sets ...  {'CNTY_OR_CITY': 'NOTTOWAY', 'COLLECT_DT': '2015-12-30', 'Lead_Amount_mg_L': 4.53}, {'CNTY_OR_CITY': 'NOTTOWAY', 'COLLECT_DT': '2015-12-30', 'Lead_Amount_mg_L': 0.0})]
# (Background on this error at: http://sqlalche.me/e/13/f405)

# %% [markdown]
# ### Use pandas to load json converted DataFrame into database

# %%
new_customer_location_df.to_sql(name='customer_location', con=engine, if_exists='append', index=False)

# %% [markdown]
# ### Confirm data has been added by querying the customer_name table
# * NOTE: can also check using pgAdmin

# %%
pd.read_sql_query('select * from customer_name', con=engine).head()
# Out:
#    id first_name last_name
# 0   1    Benetta   Cancott
# 1   2     Lilyan    Cherry
# 2   3    Ezekiel   Benasik
# 3   4    Kennedy     Atlay
# 4   5    Sanford    Salmen

# %% [markdown]
# ### Confirm data has been added by querying the customer_location table

# %%
pd.read_sql_query('select * from customer_location', con=engine).head()
# Out:
#    id                address  us_state
# 0   1  043 Mockingbird Place   Indiana
# 1   2       4 Prentice Point   Indiana
# 2   3      46 Derek Junction     Texas
# 3   4  11966 Old Shore Place  Missouri
# 4   5     5 Evergreen Circle  New York
